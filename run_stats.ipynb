# %%
interstate = 0
interstate_success = 0

urban = 0
urban_success = 0

highway = 0
highway_success = 0

comfort = 0
comfort_success = 0

critical = 0
critical_success = 0

evasive = 0
evasive_success = 0

cut_in = 0
cut_in_success = 0

illegal_cutin = 0
illegal_cutin_success = 0

intersection = 0
intersection_success = 0

lane_change = 0
lane_change_success = 0

lane_following = 0
lane_following_success = 0

merging_lanes = 0
merging_lanes_success = 0

multi_lane = 0
multi_lane_success = 0

oncoming_traffic = 0
oncoming_traffic_success = 0

no_oncoming_traffic = 0
no_oncoming_traffic_success = 0

parallel_lanes = 0
parallel_lanes_success = 0

race_track = 0
race_track_success = 0

roundabout = 0
roundabout_success = 0

rural = 0
rural_success = 0

simulated = 0
simulated_success = 0

single_lane = 0
single_lane_success = 0

slip_road = 0
slip_road_success = 0

speed_limit = 0
speed_limit_success = 0

traffic_jam = 0
traffic_jam_success = 0

turn_left = 0
turn_left_success = 0

turn_right = 0
turn_right_success = 0

two_lane = 0
two_lane_success = 0

emergency_braking = 0
emergency_braking_success = 0

def sort_scenario(scenario, is_success):
    for tag in scenario.tags:
        if (is_success):
            if tag == Tag.INTERSTATE:
                global interstate_success
                interstate_success += 1

            elif tag == Tag.URBAN:
                global urban_success
                urban_success +=1

            elif tag == Tag.HIGHWAY:
                global highway_success
                highway_success += 1

            elif tag == Tag.COMFORT:
                global comfort_success 
                comfort_success += 1

            elif tag == Tag.CRITICAL:
                global critical_success
                critical_success += 1

            elif tag == Tag.EVASIVE:
                global evasive_success
                evasive_success += 1

            elif tag == Tag.CUT_IN:
                global cut_in_success
                cut_in_success += 1

            elif tag == Tag.ILLEGAL_CUTIN:
                global illegal_cutin_success
                illegal_cutin_success += 1

            elif tag == Tag.INTERSECTION:
                global intersection_success
                intersection_success += 1

            elif tag == Tag.LANE_CHANGE: 
                global lane_change_success
                lane_change_success += 1

            elif tag == Tag.LANE_FOLLOWING:
                global lane_following_success
                lane_following_success += 1

            elif tag == Tag.MERGING_LANES:
                global merging_lanes_success
                merging_lanes_success += 1

            elif tag == Tag.MULTI_LANE:
                global multi_lane_success
                multi_lane_success += 1

            elif tag == Tag.ONCOMING_TRAFFIC:
                global oncoming_traffic_success
                oncoming_traffic_success += 1

            elif tag == Tag.NO_ONCOMING_TRAFFIC:
                global no_oncoming_traffic_success
                no_oncoming_traffic_success += 1

            elif tag == Tag.PARALLEL_LANES:
                global parallel_lanes_success
                parallel_lanes_success += 1

            elif tag == Tag.RACE_TRACK:
                global race_track_success
                race_track_success += 1

            elif tag == Tag.ROUNDABOUT:
                global roundabout_success
                roundabout_success += 1

            elif tag == Tag.RURAL:
                global rural_success
                rural_success += 1

            if tag == Tag.SIMULATED:
                global simulated_success
                simulated_success += 1

            elif tag == Tag.SINGLE_LANE:
                global single_lane_success
                single_lane_success += 1

            elif tag == Tag.SLIP_ROAD:
                global slip_road_success
                slip_road_success += 1

            elif tag == Tag.SPEED_LIMIT:
                global speed_limit_success
                speed_limit_success += 1

            elif tag == Tag.TRAFFIC_JAM:
                global traffic_jam_success
                traffic_jam_success += 1

            elif tag == Tag.TURN_LEFT:
                global turn_left_success
                turn_left_success += 1

            elif tag == Tag.TURN_RIGHT:
                global turn_right_success
                turn_right_success += 1

            elif tag == Tag.TWO_LANE:
                global two_lane_success
                two_lane_success += 1

            elif tag == Tag.EMERGENCY_BRAKING:
                global emergency_braking_success
                emergency_braking_success += 1
        else:
            if tag == Tag.INTERSTATE:
                global interstate
                interstate += 1

            elif tag == Tag.URBAN:
                global urban
                urban +=1

            elif tag == Tag.HIGHWAY:
                global highway
                highway += 1

            elif tag == Tag.COMFORT:
                global comfort 
                comfort += 1

            elif tag == Tag.CRITICAL:
                global critical
                critical += 1

            elif tag == Tag.EVASIVE:
                global evasive
                evasive += 1

            elif tag == Tag.CUT_IN:
                global cut_in
                cut_in += 1

            elif tag == Tag.ILLEGAL_CUTIN:
                global illegal_cutin
                illegal_cutin += 1

            elif tag == Tag.INTERSECTION:
                global intersection
                intersection += 1

            elif tag == Tag.LANE_CHANGE: 
                global lane_change
                lane_change += 1

            elif tag == Tag.LANE_FOLLOWING:
                global lane_following
                lane_following += 1

            elif tag == Tag.MERGING_LANES:
                global merging_lanes
                merging_lanes += 1

            elif tag == Tag.MULTI_LANE:
                global multi_lane
                multi_lane += 1

            elif tag == Tag.ONCOMING_TRAFFIC:
                global oncoming_traffic
                oncoming_traffic += 1

            elif tag == Tag.NO_ONCOMING_TRAFFIC:
                global no_oncoming_traffic
                no_oncoming_traffic += 1

            elif tag == Tag.PARALLEL_LANES:
                global parallel_lanes
                parallel_lanes += 1

            elif tag == Tag.RACE_TRACK:
                global race_track
                race_track += 1

            elif tag == Tag.ROUNDABOUT:
                global roundabout
                roundabout += 1

            elif tag == Tag.RURAL:
                global rural
                rural += 1

            if tag == Tag.SIMULATED:
                global simulated
                simulated += 1

            elif tag == Tag.SINGLE_LANE:
                global single_lane
                single_lane += 1

            elif tag == Tag.SLIP_ROAD:
                global slip_road
                slip_road += 1

            elif tag == Tag.SPEED_LIMIT:
                global speed_limit
                speed_limit += 1

            elif tag == Tag.TRAFFIC_JAM:
                global traffic_jam
                traffic_jam += 1

            elif tag == Tag.TURN_LEFT:
                global turn_left
                turn_left += 1

            elif tag == Tag.TURN_RIGHT:
                global turn_right
                turn_right += 1

            elif tag == Tag.TWO_LANE:
                global two_lane
                two_lane += 1

            elif tag == Tag.EMERGENCY_BRAKING:
                global emergency_braking
                emergency_braking += 1
                
def print_stats():
    print(f"Interstate solutions found: {interstate_success}/{interstate}")
    print(f"Urban solutions found: {urban_success}/{urban}")
    print(f"Highway solutions found: {highway_success}/{highway}")
    print(f"Comfort solutions found: {comfort_success}/{comfort}")
    print(f"Critical solutions found: {critical_success}/{critical}")
    print(f"Evasive solutions found: {evasive_success}/{evasive}")
    print(f"Cut in solutions found: {cut_in_success}/{cut_in}")
    print(f"Illegal cut in solutions found: {illegal_cutin_success}/{illegal_cutin}")
    print(f"Intersection solutions found: {intersection_success}/{intersection}")
    print(f"Lane change solutions found: {lane_change_success}/{lane_change}")
    print(f"Lane following solutions found: {lane_following_success}/{lane_following}")
    print(f"Merging lanes solutions found: {merging_lanes_success}/{merging_lanes}")
    print(f"Multi lane solutions found: {multi_lane_success}/{multi_lane}")
    print(f"Oncoming traffic solutions found: {oncoming_traffic_success}/{oncoming_traffic}")
    print(f"Parallel lanes solutions found: {parallel_lanes_success}/{parallel_lanes}")
    print(f"Race track solutions found: {race_track_success}/{race_track}")
    print(f"Roundabout solutions found: {roundabout_success}/{roundabout}")
    print(f"Rural solutions found: {rural_success}/{rural}")
    print(f"Simulated solutions found: {simulated_success}/{simulated}")
    print(f"Single lane solutions found: {single_lane_success}/{single_lane}")
    print(f"Slip road solutions found: {slip_road_success}/{slip_road}")
    print(f"Speed limit solutions found: {speed_limit_success}/{speed_limit}")
    print(f"Traffic jam solutions found: {traffic_jam_success}/{traffic_jam}")
    print(f"Turn left solutions found: {turn_left_success}/{turn_left}")
    print(f"Turn right solutions found: {turn_right_success}/{turn_right}")
    print(f"Two lane solutions found: {two_lane_success}/{two_lane}")
    print(f"Emergency braking solutions found: {emergency_braking_success}/{emergency_braking}")

# %%
import os
import re
from commonroad.common.file_reader import CommonRoadFileReader
from commonroad.scenario.scenario import Tag


'''
# Regex used to match relevant loglines (in this case, a specific IP address)
start_regex = re.compile(r"==============================        Solution found        ==============================")
stop_regex = re.compile(r"==============================  Solution found but invalid  ==============================")

reached_start = False
reached_end = False

# Edit path to scenarios
scenarios_path = "../../commonroad-scenarios-master/"

for filename in os.listdir(scenarios_path):
    if filename.endswith(".xml"):
        scenario, planning_problem_set = CommonRoadFileReader(scenarios_path + filename).open()
        sort_scenario(scenario, False)
'''
# Edit path to output log
log_path = "../logs/log_2021_05_25_17-02-35.log"
        
with open(log_path, "r") as file:
    line = file.readline()
    while not reached_start:
        if (start_regex.search(line)):
            reached_start = True
        else:
            line = file.readline()
    while not reached_end:
        line = file.readline()
        if (stop_regex.search(line)):
            reached_end = True
        else: 
            scenario_id = line[3:].strip()
            path = scenarios_path + scenario_id + '.xml'
            scenario, planning_problem_set = CommonRoadFileReader(path).open()
            sort_scenario(scenario, True)
print_stats()
# Out:
# Interstate solutions found: 0/1
# Urban solutions found: 59/695
# Highway solutions found: 80/238
# Comfort solutions found: 46/228
# Critical solutions found: 347/521
# Evasive solutions found: 6/17
# Cut in solutions found: 0/0
# Illegal cut in solutions found: 1/1
# Intersection solutions found: 333/1115
# Lane change solutions found: 71/229
# Lane following solutions found: 16/60
# Merging lanes solutions found: 27/82
# Multi lane solutions found: 88/245
# Oncoming traffic solutions found: 56/647
# Parallel lanes solutions found: 103/269
# Race track solutions found: 0/1
# Roundabout solutions found: 0/1
# Rural solutions found: 4/7
# Simulated solutions found: 304/473
# Single lane solutions found: 28/78
# Slip road solutions found: 32/91
# Speed limit solutions found: 28/111
# Traffic jam solutions found: 6/23
# Turn left solutions found: 18/574
# Turn right solutions found: 1/13
# Two lane solutions found: 16/565
# Emergency braking solutions found: 1/6

# %%
count = 0
for filename in os.listdir("../../commonroad-scenarios-master/"):
    if filename.endswith(".xml"):
        count+=1
        
print(count)
# Out:
# 1403

# %%
# Edit path to output log
count = 0
log_path = "../logs/log_2021_05_25_17-02-35.log"

start_regex = re.compile(r"==============================        Search Results        ==============================")
stop_regex = re.compile(r"==============================        Solution found        ==============================")

reached_start = False
reached_end = False
        
with open(log_path, "r") as file:
    line = file.readline()
    while not reached_start:
        if (start_regex.search(line)):
            reached_start = True
        else:
            line = file.readline()
    while not reached_end:
        line = file.readline()
        if (stop_regex.search(line)):
            reached_end = True
        else: 
            count+=1
print(count)
# Out:
# 0
